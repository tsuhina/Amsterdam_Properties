# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load all three datasets:
data_prices = pd.read_csv('houses_price.csv')
data_address = pd.read_csv('houses_address.csv')
data_details = pd.read_csv('houses_details.csv')
data_population = pd.read_csv('houses_population.csv')
data_neighbourhood = pd.read_csv('houses_neighborhood.csv', encoding='latin-1')

# %%
data_neighbourhood.head()
# Out:
#                                         treinstation  \
# 0  ['Amsterdam Lelylaan', '877 meter', 'Slotervaa...
# 1         ['Diemen', '1,9 kilometer', 'IJburg West']
# 2  ['Amsterdam Lelylaan', '3,4 kilometer', 'Midde...
# 3  ['Amsterdam Centraal', '2,9 kilometer', 'Banne...
# 4           ['Diemen', '4,1 kilometer', 'Waterland']
#
#                                          tankstation  \
# 0  ['Shell Station Postjesweg', '905 meter', 'Slo...
# 1  ['Shell Station Kriterion', '1,3 kilometer', '...
# 2  ['Demarol Badhoevedrop', '559 meter', 'Middelv...
# 3  ['Total Selfservicestation Kadoelen', '1,7 kil...
# 4  ['Shell Station Kriterion', '1,8 kilometer', '...
#
#                                           supermarkt  \
# 0  ['Wereld-Mini-Markt', '274 meter', 'Slotervaart']
# 1  ['Multi Tokorien IJburg', '1,9 kilometer', 'IJ...
# 2  ['Supermarkt Karadeniz', '925 meter', 'Middelv...
# 3  ['Son To Maatje', '339 meter', 'Banne Buiksloot']
# 4  ['Bizim Ufuk Supermarket en Bakkerij (A.I.)', ...
#
#                                          basisschool  \
# 0      ['Pro Regeschool', '60 meter', 'Slotervaart']
# 1  ['Abbs-de Zuiderzee', '554 meter', 'IJburg West']
# 2  ['CBS Oranje Nassau', '586 meter', 'Middelveld...
# 3  ['Rijkers Openbare Basisschool Dorus', '359 me...
# 4    ['Weidevogel De', '1,6 kilometer', 'Waterland']
#
#                                         kinderopvang  \
# 0  ['Kings & Queens BSO', '69 meter', 'Slotervaart']
# 1  ['Blauwe Fluithaas De', '178 meter', 'IJburg W...
# 2  ['PVO Harlekijntje', '251 meter', 'Middelvelds...
# 3  ['Gastouder De Liefste Mama', '348 meter', 'Ba...
# 4  ['KinderVilla ijburg steigereiland nso', '1,5 ...
#
#                                    middelbare school  \
# 0  ['Hervormd Lyceum West', '235 meter', 'Sloterv...
# 1  ['LUCA Praktijkschool', '2,5 kilometer', 'IJbu...
# 2  ['Calandlyceum', '1,6 kilometer', 'Middelvelds...
# 3   ['Bredero Mavo', '814 meter', 'Banne Buiksloot']
# 4  ['LUCA Praktijkschool', '3,7 kilometer', 'Wate...
#
#                                                cafÃ©  \
# 0  ['Kleine Nachtwacht VOF De', '968 meter', 'Slo...
# 1   ['CafÃ© Blond B.V.', '429 meter', 'IJburg West']
# 2  ["Louman's Hoekje CafÃ©", '181 meter', 'Middel...
# 3  ['EetcafÃ© The Mansion', '962 meter', 'Banne B...
# 4  ['Zwaan Hotel-CafÃ© CV De', '1,7 kilometer', '...
#
#                                           videotheek  \
# 0  ['Sloterplas Cinema Super Videotheek De', '649...
# 1  ['Movie MAX Moviestores', '3,1 kilometer', 'IJ...
# 2  ['Filmclub Videotheek Osdorp', '788 meter', 'M...
# 3  ['Eurocorner', '2,3 kilometer', 'Banne Buikslo...
# 4  ['Movie MAX Moviestores', '4,2 kilometer', 'Wa...
#
#                                           (huis)arts  \
# 0    ['Umans-Mohan V I', '914 meter', 'Slotervaart']
# 1  ['Gezondheidscentrum Steigereiland SAG', '262 ...
# 2  ['Universum Care', '153 meter', 'Middelveldsch...
# 3  ['Huisartsenpraktijk Kadoelerbreek', '780 mete...
# 4  ['Gezondheidscentrum Steigereiland SAG', '2,0 ...
#
#                                             tandarts  \
# 0  ['Tandartspraktijk H T D Nguyen', '163 meter',...
# 1  ['Mondzorgcentrum IJburg', '294 meter', 'IJbur...
# 2  ['Zygogiannis K', '447 meter', 'Middelveldsche...
# 3  ['tandheelkundige dienstverlening Sang Ajang',...
# 4  ['Tandartsen Praktijk Amsterdam Ijburg', '1,9 ...
#
#                                       fitnesscentrum  \
# 0  ['Fitness Centre Palestra', '1,0 kilometer', '...
# 1       ['Fitamsterdam', '691 meter', 'IJburg West']
# 2  ['Back in Shape', '931 meter', 'Middelveldsche...
# 3  ['Cardio Candy', '2,0 kilometer', 'Banne Buiks...
# 4     ['Fitamsterdam', '2,2 kilometer', 'Waterland']
#
#                                          bibliotheek
# 0  ['Praktizijns SociÃ«teit Bibliotheek', '3,9 ki...
# 1  ['Internationaal Instituut voor Sociale Geschi...
# 2  ['Praktizijns SociÃ«teit Bibliotheek', '5,3 ki...
# 3  ['Toonkunst-Bibliotheek', '3,0 kilometer', 'Ba...
# 4  ['Internationaal Instituut voor Sociale Geschi...

# %%
######################################################################
###################INSERT FUNCTIONS HERE##############################
######################################################################

# NEIGHBOURHOOD
# extract distances from the points of interest:
import ast
import re
def extractDistances(x):
    if str(x) != 'nan':
        x = ast.literal_eval(x)[1]
        word_list = x.split(' ') 
        distance = word_list[0]
        units = word_list[1]
        distance = float(distance.replace(',', '.'))
        if units == 'kilometer':
            distance = distance*1000
    else: 
        distance = np.nan
    return distance

# DETAILS
# use this function on any column that has m, m^2, m^3 in it
# make for data_details dataframe.
def removeUnitsMeters(x):
    if str(x) not in ['-', 'nan', 'NaN']:
        if isinstance(x, float):
            x = x
        else:
            x = float(x.split(' ')[0])
    else:
        x = np.nan
    return x

# POPULATION
# apply to: data_population.distribution_fm = data_population.distribution_fm.apply(female_to_male_ratio)
def female_to_male_ratio(x):
    if (str(x) not in ['nan', 'NaN', '-']):
        info_both = re.findall("\d+\.\d+", x)
        if len(info_both)>1:
            males = float(info_both[1])
            females = float(info_both[0])
            ratio = females/males
        else:
            ratio = np.nan
    else:
        ratio = np.nan
    return ratio

def get_population_density(x):
    if (str(x) not in ['nan', 'NaN', '-']):
        info_both = re.findall("\d+\.\d+", x)
        if len(info_both)>0:
            density = float(info_both[0])
        else:
            density = np.nan
    else:
        density = np.nan
    return density

# returns percentages
def get_percentage(x):
    if (str(x) not in ['nan', 'NaN', '-']):
        info_both = re.findall("\d+\.\d+", x)
        if len(info_both)==0:
            info_both = re.findall("\d+", x)
            if len(info_both)>0:
                percentage = float(info_both[0])
                if len(info_both)>1:
                    percentage = percentage + float(info_both[1])/100
            else:
                percentage = np.nan
        elif len(info_both)>1:
            percentage = float(info_both[0]) + float(info_both[1])/100
    else:
        percentage = np.nan
    return percentage/100

def remove_currency(x):
    if (str(x) not in ['nan', 'NaN', '-']):
        info_both = re.findall("\d+\.\d+", x)
        if len(info_both)>0:
            euros = float(info_both[0])
        else:
            euros = np.nan
        return euros

# PRICES:

def fix_price(x):
    price_list = re.findall("\d+", x)
    if len(price_list)>0:
        if len(price_list)>2:
            price = float(price_list[0])*1e6 + float(price_list[1])*1e3 + float(price_list[2])
        elif len(price_list) == 2:
            price = float(price_list[0])*1e3 + float(price_list[1])
        elif len(price_list) == 1:
            price = float(price_list[0])*1e3
    else:
        price = 0
    return price

# remove letters from zip codes:
def remove_letters_zipcode(x):
    zipcode = re.findall("\d+", x)
    if len(zipcode)==1:
        to_return = int(zipcode[0])
    else:
        to_return = np.nan
    return to_return

# %%
# Use extractDistances(x) to get relevant information from the neighbourhood dataframe:
data_neighbourhood = data_neighbourhood.applymap(extractDistances)

# Use removeUnitsMeters to remove m2 and m3 from specific columns
data_details.Living_area = data_details.Living_area.apply(removeUnitsMeters)
data_details.LOT = data_details.LOT.apply(removeUnitsMeters)
data_details.Plot = data_details.Plot.apply(removeUnitsMeters)

# Fix female to male ratio:
data_population.distribution_fm = data_population.distribution_fm.apply(female_to_male_ratio)

# Fix population density:
data_population.population_density = data_population.population_density.apply(get_population_density)

# Fix population columns:
perc_cols = ['Age_0-15', 'age_15-25', 'age_25-45', 'age_45-65', 'age_older', 'indigenous', 'western_allochtoon', 'none_western', 'household_single', 'household_wo_kids', 'household_with_kids', 'perc_with_job', 'high_income', 'medium_income', 'low_income', 'social_benefit'] 
data_population.loc[:, perc_cols] = data_population.loc[:, perc_cols].applymap(get_percentage)
data_population.loc[:, 'income_avg'] = data_population.loc[:, 'income_avg'].apply(remove_currency)

# Fix property prices:
cols_to_fix = ['current_price', 'original_price', 'changes_in_price']
data_prices.loc[:, cols_to_fix] = data_prices.loc[:, cols_to_fix].applymap(fix_price)

# Fix zipcodes:
data_address.Zipcode = data_address.Zipcode.apply(remove_letters_zipcode)

# %%
# Concatenate all data to get a complete data frame:
data_frame = pd.concat([data_address, data_prices, data_details, data_neighbourhood, data_population], axis=1)

# %% [markdown]
# At this point, we got out dataset. But we do not neeed all of the variables that are listed in there. For this reason, I will remove some that we do not need in our model.

# %%
data_frame.drop(columns = ['times_in_sales','Graden', 'Price', 'price', 'original_price', 'Balcony', 'Garage', 'view', 'inside_maintenance_state', 'outside_maintenace_state', 'outside_state_painting', 'kitchen', 'Sanitation', 'Energy_consumption', 'Other','Insulation','Heating', 'Energy_label', 'Broker', 'posted_date', 'number_of_times_shown', 'number_of_times_shown_yesterday', 'videotheek', 'changes_in_price'], inplace = True)

# %%
data_frame.head(20)
# Out:
#                               Street  Zipcode current_price price_per_m2  \
# 0              Spyridon Louisweg 117   1034.0        585000        3.656
# 1          Philip Vingboonsstraat 16   1067.0        325000        3.250
# 2               Edmond Halleylaan 58   1086.0        910000        3.889
# 3                    Leliegracht 5 2   1016.0      1.05e+06        7.554
# 4                      Zuideinde 286   1035.0     1.395e+06        4.619
# 5               Durgerdammerdijk 119   1026.0        700000        6.796
# 6           Eerste Helmersstraat 201   1054.0      1.65e+06        5.789
# 7                   Surinamekade 5 D   1019.0     1.589e+06        4.966
# 8                    Betuwestraat 14   1079.0      1.95e+06        8.744
# 9             Nieuwe Leliestraat 186   1015.0        850000        6.071
# 10                   Kadoelenweg 380   1035.0        975000        6.771
# 11                        Diopter 80   1025.0        539080        3.594
# 12                    Kwekerijlaan 8   1036.0        500000        3.876
# 13               Willem Mulierhof 45   1067.0        800000        6.780
# 14               Galileiplantsoen 34   1098.0        800000        6.061
# 15                 Koninginneweg 155   1075.0       2.3e+06        8.127
# 16                 Schimmelstraat 55   1053.0      1.29e+06        8.958
# 17       Oudezijds Voorburgwal 217 B   1012.0      1.05e+06        8.140
# 18  Carolina Macgillavrylaan 29 + Pp   1098.0        569000        4.948
# 19                    Gunterstein 51   1081.0        575000        4.873
#
#                    Type Construction_year  Living_area      LOT    Plot Rooms  \
# 0             Herenhuis              1995        160.0  556.000  220.00     5
# 1            Hoekwoning              1955        100.0  328.000   80.00     5
# 2             Herenhuis              2008        234.0  874.000  144.00     8
# 3   Dubbele bovenwoning              1620        139.0      NaN   66.00     5
# 4    Vrijstaande woning              1751        302.0    1.259    1.47     7
# 5       Eengezinswoning              1968        103.0  319.000  265.00     5
# 6          Tussenwoning              1904        285.0    1.043   90.00    10
# 7              Woonboot              1936        320.0  735.000    1.00    11
# 8                Woning              1968        223.0  903.000  228.00     9
# 9             Herenhuis              1005        140.0  500.000   48.00     4
# 10            Herenhuis              1930        144.0  570.000  505.00     4
# 11         Tussenwoning              1998        150.0  470.000  167.00     5
# 12      Eengezinswoning              2008        129.0  469.000  109.00     6
# 13             Bungalow              1965        118.0  534.000  726.00     3
# 14            Herenhuis              1929        132.0  501.000  120.00     7
# 15               Woning              1906        283.0    1.132     NaN     7
# 16            Herenhuis              1981        144.0  484.000   49.00     6
# 17          Appartement              1005        129.0      NaN     NaN     3
# 18          Appartement              2013        115.0  352.000     NaN     4
# 19      Eengezinswoning              1962        118.0      NaN  185.00     5
#
#          ...       household_single  household_wo_kids  household_with_kids  \
# 0        ...                   0.43               0.21                 0.37
# 1        ...                   0.43               0.20                 0.37
# 2        ...                   0.30               0.18                 0.53
# 3        ...                   0.65               0.23                 0.12
# 4        ...                   0.36               0.24                 0.40
# 5        ...                   0.29               0.32                 0.39
# 6        ...                   0.64               0.19                 0.18
# 7        ...                   0.43               0.25                 0.33
# 8        ...                   0.57               0.22                 0.21
# 9        ...                   0.69               0.18                 0.13
# 10       ...                   0.27               0.33                 0.40
# 11       ...                   0.50               0.22                 0.27
# 12       ...                   0.44               0.25                 0.31
# 13       ...                   0.43               0.20                 0.37
# 14       ...                   0.48               0.22                 0.30
# 15       ...                   0.50               0.22                 0.28
# 16       ...                   0.65               0.20                 0.15
# 17       ...                   0.72               0.19                 0.09
# 18       ...                   0.48               0.22                 0.30
# 19       ...                   0.59               0.24                 0.18
#
#     avg_person_per_household  perc_with_job  high_income  medium_income  \
# 0                        2,2           0.63         0.11           0.46
# 1                        2,2           0.62         0.09           0.45
# 2                        2,6           0.81         0.37           0.40
# 3                        1,5           0.69         0.44           0.26
# 4                        2,2           0.73         0.20           0.44
# 5                        2,4           0.76         0.36           0.34
# 6                        1,6           0.76         0.31           0.37
# 7                        2,0           0.80         0.40           0.37
# 8                        1,7           0.77         0.32           0.39
# 9                        1,4           0.72         0.26           0.37
# 10                       2,3           0.75         0.21           0.37
# 11                       1,9           0.64         0.15           0.44
# 12                       2,0           0.69         0.08           0.45
# 13                       2,2           0.62         0.09           0.45
# 14                       2,0           0.78         0.34           0.39
# 15                       2,0           0.74         0.44           0.28
# 16                       1,5           0.72         0.18           0.40
# 17                       1,4           0.72         0.22           0.37
# 18                       2,0           0.78         0.34           0.39
# 19                       1,6           0.71         0.28           0.40
#
#     low_income  income_avg  social_benefit
# 0         0.43        16.4          0.1007
# 1         0.46        15.5          0.1107
# 2         0.23        23.4          0.0500
# 3         0.30        30.2          0.0100
# 4         0.36        17.9          0.0505
# 5         0.30        24.3          0.0005
# 6         0.32        22.3          0.0405
# 7         0.23        24.8          0.0408
# 8         0.29        22.6          0.0300
# 9         0.37        21.0          0.0601
# 10        0.42        18.3          0.0207
# 11        0.41        17.3          0.0801
# 12        0.47        15.3          0.0607
# 13        0.46        15.5          0.1107
# 14        0.27        23.2          0.0203
# 15        0.28        33.3          0.0205
# 16        0.42        17.5          0.0900
# 17        0.41        18.9          0.0309
# 18        0.27        23.2          0.0203
# 19        0.32        23.2          0.0208
#
# [20 rows x 44 columns]

# %%
nr_null = data_frame.isnull().sum(axis = 0)

# %%
g = sns.barplot(y = nr_null, x = nr_null.index)
g.set_xticklabels(labels = nr_null.index, rotation = 90)
plt.show()
